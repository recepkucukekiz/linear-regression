# %%
import matplotlib.pyplot as plt
from statistics import mean
import numpy as np

# %%
file = open('ex1data1.txt', 'r')
lines = file.read().splitlines()

org_x = list(map(lambda l: float(l.split(',')[0]), lines))
org_y = list(map(lambda l: float(l.split(',')[1]), lines))

# %%
plt.style.use('fivethirtyeight')
plt.scatter(np.array(org_x), np.array(org_y), color='black')
plt.gca().set_title("Dataset",fontsize = 14)

plt.show()

# %%
x = np.array(org_x) 
y = np.array(org_y)

# %%
def predict(x, theta0, theta1):
    return theta1*x + theta0

def cost(x, y, theta0, theta1):
    m = x.shape[0]

    summation = 0
    for it in range(m):
        summation += ((predict(x[it],theta0, theta1) - y[it])**2)
    
    J = (1/(2*m)) * summation
    return J

def fit(x, y, theta0, theta1, iterations, learning_rate):
    m = x.shape[0]
    costs = []
    
    for _ in range(iterations):
        theta0 = theta0 - (learning_rate * (1/m) * np.sum((theta1*x + theta0) - y))
        theta1 = theta1 - (learning_rate * (1/m) * np.sum(x*((theta1*x + theta0) - y))) 
        
        costs.append(cost(x,y,theta0,theta1))
        
    return theta0, theta1, costs

def validate(value, theta0, theta1):
    denormalised_value = value * (max_x - min_x) + min_x
    constant = value / denormalised_value
    return predict(denormalised_value, theta0*constant, theta1*constant)

# %%
def draw_plot(x, y, theta0, theta1, iterations, costs):
    plt.scatter(x, y, color='black')
    plt.plot(x, predict(x, theta0, theta1))
    plt.gca().set_title("Linear Regressor Problem",fontsize = 14)

    plt.show()

    # plt.scatter(np.arange(iterations), costs, color='black')
    plt.plot(np.arange(iterations), costs)
    plt.gca().set_title("J(Q) vs Iteration",fontsize = 14)

    plt.show()

def train(x, y, initial_theta0, initial_theta1, iterations, learning_rate):
    theta0, theta1, costs = fit(x, y, initial_theta0, initial_theta1, iterations, learning_rate)

    print(" theta0:", theta0, "\n", "theta1:", theta1)
    draw_plot(x, y, theta0, theta1, iterations, costs)

    return theta0, theta1

# %%
train(x, y, initial_theta0= 0, initial_theta1= 1, iterations= 100, learning_rate= 1)
# Out:
#  theta0: -1.2960069328551686e+113
#  theta1: -2.195261919746826e+113
# (-1.2960069328551686e+113, -2.195261919746826e+113)

# %%
train(x, y, initial_theta0= 0, initial_theta1= 1, iterations= 100, learning_rate= 0.1)
# Out:
#  theta0: 9.37490383539567e+79
#  theta1: 8.565095101009231e+80
# (9.37490383539567e+79, 8.565095101009231e+80)

# %%
train(x, y, initial_theta0= 0, initial_theta1= 1, iterations= 100, learning_rate= 0.01)
# Out:
#  theta0: -0.6644491440221083
#  theta1: 0.8689953884657315
# (-0.6644491440221083, 0.8689953884657315)

# %%
th0, th1 = train(x, y, initial_theta0= 0, initial_theta1= 1, iterations= 5000, learning_rate= 0.01)
# Out:
#  theta0: -3.895345892193819
#  theta1: 1.192990023740026

# %%
value = 22.203
print(predict(value, th0, th1))
# Out:
# 22.592611604905976
